# %%
import requests
import pandas as pd
import streamlit as st
import cfbd
import psycopg2

# %%
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = 'XscFL3JKpF/UVy2fexpow+vZ/o6rlKfxtnQdN70yVY89w1aTyXYDO+o641kfK8zy'
configuration.api_key_prefix['Authorization'] = 'Bearer'

api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))

fav_team = 'Michigan State'
records = api_instance.get_team_records(team = f'{fav_team}')

# %%
df = pd.DataFrame.from_records([g.to_dict() for g in records])
df
# Out:
#     year  team_id            team        conference division  expected_wins  \
# 0   1918      127  Michigan State  FBS Independents                     0.0
# 1   1925      127  Michigan State  FBS Independents                     0.0
# 2   1926      127  Michigan State  FBS Independents                     0.0
# 3   1927      127  Michigan State  FBS Independents                     0.0
# 4   1928      127  Michigan State  FBS Independents                     0.0
# ..   ...      ...             ...               ...      ...            ...
# 94  2019      127  Michigan State           Big Ten     East            8.3
# 95  2020      127  Michigan State           Big Ten     East            2.6
# 96  2021      127  Michigan State           Big Ten     East            9.2
# 97  2022      127  Michigan State           Big Ten     East            3.9
# 98  2023      127  Michigan State           Big Ten     East            3.2
#
#                                                 total  \
# 0     {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 1     {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
# 2     {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
# 3     {'games': 9, 'wins': 4, 'losses': 5, 'ties': 0}
# 4     {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
# ..                                                ...
# 94   {'games': 13, 'wins': 7, 'losses': 6, 'ties': 0}
# 95    {'games': 7, 'wins': 2, 'losses': 5, 'ties': 0}
# 96  {'games': 13, 'wins': 11, 'losses': 2, 'ties': 0}
# 97   {'games': 12, 'wins': 5, 'losses': 7, 'ties': 0}
# 98    {'games': 8, 'wins': 2, 'losses': 6, 'ties': 0}
#
#                                    conference_games  \
# 0   {'games': 1, 'wins': 1, 'losses': 0, 'ties': 0}
# 1   {'games': 3, 'wins': 1, 'losses': 2, 'ties': 0}
# 2   {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}
# 3   {'games': 1, 'wins': 0, 'losses': 1, 'ties': 0}
# 4   {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}
# ..                                              ...
# 94  {'games': 9, 'wins': 4, 'losses': 5, 'ties': 0}
# 95  {'games': 7, 'wins': 2, 'losses': 5, 'ties': 0}
# 96  {'games': 9, 'wins': 7, 'losses': 2, 'ties': 0}
# 97  {'games': 9, 'wins': 3, 'losses': 6, 'ties': 0}
# 98  {'games': 5, 'wins': 0, 'losses': 5, 'ties': 0}
#
#                                          home_games  \
# 0   {'games': 5, 'wins': 4, 'losses': 1, 'ties': 0}
# 1   {'games': 5, 'wins': 3, 'losses': 2, 'ties': 0}
# 2   {'games': 4, 'wins': 3, 'losses': 1, 'ties': 0}
# 3   {'games': 5, 'wins': 4, 'losses': 1, 'ties': 0}
# 4   {'games': 5, 'wins': 3, 'losses': 2, 'ties': 0}
# ..                                              ...
# 94  {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 95  {'games': 4, 'wins': 1, 'losses': 3, 'ties': 0}
# 96  {'games': 6, 'wins': 6, 'losses': 0, 'ties': 0}
# 97  {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 98  {'games': 5, 'wins': 2, 'losses': 3, 'ties': 0}
#
#                                          away_games
# 0   {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}
# 1   {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}
# 2   {'games': 4, 'wins': 0, 'losses': 4, 'ties': 0}
# 3   {'games': 4, 'wins': 0, 'losses': 4, 'ties': 0}
# 4   {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}
# ..                                              ...
# 94  {'games': 5, 'wins': 2, 'losses': 3, 'ties': 0}
# 95  {'games': 3, 'wins': 1, 'losses': 2, 'ties': 0}
# 96  {'games': 6, 'wins': 4, 'losses': 2, 'ties': 0}
# 97  {'games': 5, 'wins': 1, 'losses': 4, 'ties': 0}
# 98  {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}
#
# [99 rows x 10 columns]

# %%
con_str = 'mongodb+srv://andrew:coldbeer@weather.tf7msba.mongodb.net/?retryWrites=true&w=majority'
import pymongo

client = pymongo.MongoClient(con_str)

# %%
# Create databases

db = client.db

# Create a collection from the database
teams = db.teams

# %%
# Set the dataframe index to the ID column:
df.set_index('team_id', inplace=True)

# %%
for i in df.index:
    teams.insert_one(df.loc[i].to_dict())
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\src\test.ipynb Cell 7 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/adoro/OneDrive/Documents/GitHub/Capstone-Project/src/test.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> for i in df.index:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/adoro/OneDrive/Documents/GitHub/Capstone-Project/src/test.ipynb#X52sZmlsZQ%3D%3D?line=1'>2</a>     teams.insert_one(df.loc[i].to_dict())
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\collection.py:671, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     667     document["_id"] = ObjectId()  # type: ignore[index]
#     669 write_concern = self._write_concern_for(session)
#     670 return InsertOneResult(
# --> 671     self._insert_one(
#     672         document,
#     673         ordered=True,
#     674         write_concern=write_concern,
#     675         op_id=None,
#     676         bypass_doc_val=bypass_document_validation,
#     677         session=session,
#     678         comment=comment,
#     679     ),
#     680     write_concern.acknowledged,
#     681 )
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\collection.py:611, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     599     result = conn.command(
#     600         self.__database.name,
#     601         command,
#    (...)
#     606         retryable_write=retryable_write,
#     607     )
#     609     _check_write_command_response(result)
# --> 611 self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     613 if not isinstance(doc, RawBSONDocument):
#     614     return doc.get("_id")
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\mongo_client.py:1568, in MongoClient._retryable_write(self, retryable, func, session)
#    1566 """Internal retryable write helper."""
#    1567 with self._tmp_session(session) as s:
# -> 1568     return self._retry_with_session(retryable, func, s, None)
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\mongo_client.py:1413, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1403 """Execute an operation with at most one consecutive retries
#    1404
#    1405 Returns func()'s return value on success. On error retries the same
#    (...)
#    1408 Re-raises any exception thrown by func().
#    1409 """
#    1410 retryable = bool(
#    1411     retryable and self.options.retry_writes and session and not session.in_transaction
#    1412 )
# -> 1413 return self._retry_internal(retryable, func, session, bulk)
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\mongo_client.py:1460, in MongoClient._retry_internal(self, retryable, func, session, bulk)
#    1458                 raise last_error
#    1459             retryable = False
# -> 1460         return func(session, conn, retryable)
#    1461 except ServerSelectionTimeoutError:
#    1462     if is_retrying():
#    1463         # The application may think the write was never attempted
#    1464         # if we raise ServerSelectionTimeoutError on the retry
#    1465         # attempt. Raise the original exception instead.
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\collection.py:599, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     596 if bypass_doc_val:
#     597     command["bypassDocumentValidation"] = True
# --> 599 result = conn.command(
#     600     self.__database.name,
#     601     command,
#     602     write_concern=write_concern,
#     603     codec_options=self.__write_response_codec_options,
#     604     session=session,
#     605     client=self.__database.client,
#     606     retryable_write=retryable_write,
#     607 )
#     609 _check_write_command_response(result)
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\helpers.py:315, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     312 from pymongo.pool import Connection
#     314 try:
# --> 315     return func(*args, **kwargs)
#     316 except OperationFailure as exc:
#     317     if no_reauth:
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\pool.py:960, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     958 # Catch socket.error, KeyboardInterrupt, etc. and close ourselves.
#     959 except BaseException as error:
# --> 960     self._raise_connection_failure(error)
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\pool.py:932, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     930     self._raise_if_not_writable(unacknowledged)
#     931 try:
# --> 932     return command(
#     933         self,
#     934         dbname,
#     935         spec,
#     936         self.is_mongos,
#     937         read_preference,
#     938         codec_options,
#     939         session,
#     940         client,
#     941         check,
#     942         allowable_errors,
#     943         self.address,
#     944         listeners,
#     945         self.max_bson_size,
#     946         read_concern,
#     947         parse_write_concern_error=parse_write_concern_error,
#     948         collation=collation,
#     949         compression_ctx=self.compression_context,
#     950         use_op_msg=self.op_msg_enabled,
#     951         unacknowledged=unacknowledged,
#     952         user_fields=user_fields,
#     953         exhaust_allowed=exhaust_allowed,
#     954         write_concern=write_concern,
#     955     )
#     956 except (OperationFailure, NotPrimaryError):
#     957     raise
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\network.py:150, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     148 flags = _OpMsg.MORE_TO_COME if unacknowledged else 0
#     149 flags |= _OpMsg.EXHAUST_ALLOWED if exhaust_allowed else 0
# --> 150 request_id, msg, size, max_doc_size = message._op_msg(
#     151     flags, spec, dbname, read_preference, codec_options, ctx=compression_ctx
#     152 )
#     153 # If this is an unacknowledged write then make sure the encoded doc(s)
#     154 # are small enough, otherwise rely on the server to return an error.
#     155 if unacknowledged and max_bson_size is not None and max_doc_size > max_bson_size:
#
# File c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pymongo\message.py:765, in _op_msg(flags, command, dbname, read_preference, opts, ctx)
#     763     if ctx:
#     764         return _op_msg_compressed(flags, command, identifier, docs, opts, ctx)
# --> 765     return _op_msg_uncompressed(flags, command, identifier, docs, opts)
#     766 finally:
#     767     # Add the field back to the command.
#     768     if identifier:
#
# InvalidDocument: documents must have only string keys, key was 127

# %%
data = pd.json_normalize(df['total'])
data
# Out:
#     games  wins  losses  ties
# 0       7     4       3     0
# 1       8     3       5     0
# 2       8     3       5     0
# 3       9     4       5     0
# 4       8     3       5     0
# ..    ...   ...     ...   ...
# 94     13     7       6     0
# 95      7     2       5     0
# 96     13    11       2     0
# 97     12     5       7     0
# 98      8     2       6     0
#
# [99 rows x 4 columns]

# %%
df['total_games'] = data['games']

# %%
df['total_wins'] = data['wins']

# %%
df['total_losses'] = data['losses']

# %%
df['total_ties'] = data['ties']

# %%
data1 = pd.json_normalize(df['conference_games'])

# %%
df['total_conference_games'] = data1['games']

# %%
df['total_conference_wins'] = data1['wins']

# %%
df['total_conference_losses'] = data1['losses']

# %%
df['total_conference_ties'] = data1['ties']

# %%
df.head(2)
# Out:
#    year  team_id            team        conference division  expected_wins  \
# 0  1918      127  Michigan State  FBS Independents                     0.0
# 1  1925      127  Michigan State  FBS Independents                     0.0
#
#                                              total  \
# 0  {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 1  {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
#
#                                   conference_games  \
# 0  {'games': 1, 'wins': 1, 'losses': 0, 'ties': 0}
# 1  {'games': 3, 'wins': 1, 'losses': 2, 'ties': 0}
#
#                                         home_games  \
# 0  {'games': 5, 'wins': 4, 'losses': 1, 'ties': 0}
# 1  {'games': 5, 'wins': 3, 'losses': 2, 'ties': 0}
#
#                                         away_games  total_games  total_wins  \
# 0  {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}            7           4
# 1  {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}            8           3
#
#    total_losses  total_ties  total_conference_games  total_conference_wins  \
# 0             3           0                       1                      1
# 1             5           0                       3                      1
#
#    total_conference_losses  total_conference_ties
# 0                        0                      0
# 1                        2                      0

# %%
data2 = pd.json_normalize(df['home_games'])

# %%
df['total_home_games'] = data2['games']

# %%
df['total_home_wins'] = data2['wins']

# %%
df['total__home_losses'] = data2['losses']

# %%
df['total__home_ties'] = data2['ties']

# %%
df.head(2)
# Out:
#    year  team_id            team        conference division  expected_wins  \
# 0  1918      127  Michigan State  FBS Independents                     0.0
# 1  1925      127  Michigan State  FBS Independents                     0.0
#
#                                              total  \
# 0  {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 1  {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
#
#                                   conference_games  \
# 0  {'games': 1, 'wins': 1, 'losses': 0, 'ties': 0}
# 1  {'games': 3, 'wins': 1, 'losses': 2, 'ties': 0}
#
#                                         home_games  \
# 0  {'games': 5, 'wins': 4, 'losses': 1, 'ties': 0}
# 1  {'games': 5, 'wins': 3, 'losses': 2, 'ties': 0}
#
#                                         away_games  ...  total_losses  \
# 0  {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}  ...             3
# 1  {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}  ...             5
#
#    total_ties  total_conference_games  total_conference_wins  \
# 0           0                       1                      1
# 1           0                       3                      1
#
#    total_conference_losses  total_conference_ties  total_home_games  \
# 0                        0                      0                 5
# 1                        2                      0                 5
#
#    total_home_wins  total__home_losses  total__home_ties
# 0                4                   1                 0
# 1                3                   2                 0
#
# [2 rows x 22 columns]

# %%
data3 = pd.json_normalize(df['away_games'])

# %%
df['total_away_games'] = data3['games']

# %%
df['total_away_wins'] = data3['wins']

# %%
df['total_away_losses'] = data3['losses']

# %%
df['total_away_ties'] = data3['ties']

# %%
df.head(2)
# Out:
#    year  team_id            team        conference division  expected_wins  \
# 0  1918      127  Michigan State  FBS Independents                     0.0
# 1  1925      127  Michigan State  FBS Independents                     0.0
#
#                                              total  \
# 0  {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 1  {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
#
#                                   conference_games  \
# 0  {'games': 1, 'wins': 1, 'losses': 0, 'ties': 0}
# 1  {'games': 3, 'wins': 1, 'losses': 2, 'ties': 0}
#
#                                         home_games  \
# 0  {'games': 5, 'wins': 4, 'losses': 1, 'ties': 0}
# 1  {'games': 5, 'wins': 3, 'losses': 2, 'ties': 0}
#
#                                         away_games  ...  \
# 0  {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}  ...
# 1  {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}  ...
#
#    total_conference_losses  total_conference_ties  total_home_games  \
# 0                        0                      0                 5
# 1                        2                      0                 5
#
#    total_home_wins  total__home_losses  total__home_ties  total_away_games  \
# 0                4                   1                 0                 2
# 1                3                   2                 0                 3
#
#    total_away_wins  total_away_losses  total_away_ties
# 0                0                  2                0
# 1                0                  3                0
#
# [2 rows x 26 columns]

# %%
del df['total']

# %%
del df['conference_games']

# %%
del df['home_games']

# %%
del df['away_games']

# %%
df.head(2)
# Out:
#    year  team_id            team        conference division  expected_wins  \
# 0  1918      127  Michigan State  FBS Independents                     0.0
# 1  1925      127  Michigan State  FBS Independents                     0.0
#
#    total_games  total_wins  total_losses  total_ties  ...  \
# 0            7           4             3           0  ...
# 1            8           3             5           0  ...
#
#    total_conference_losses  total_conference_ties  total_home_games  \
# 0                        0                      0                 5
# 1                        2                      0                 5
#
#    total_home_wins  total__home_losses  total__home_ties  total_away_games  \
# 0                4                   1                 0                 2
# 1                3                   2                 0                 3
#
#    total_away_wins  total_away_losses  total_away_ties
# 0                0                  2                0
# 1                0                  3                0
#
# [2 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     99 non-null     int64
#  1   team_id                  99 non-null     int64
#  2   team                     99 non-null     object
#  3   conference               99 non-null     object
#  4   division                 99 non-null     object
#  5   expected_wins            99 non-null     float64
#  6   total_games              99 non-null     int64
#  7   total_wins               99 non-null     int64
#  8   total_losses             99 non-null     int64
#  9   total_ties               99 non-null     int64
#  10  total_conference_games   99 non-null     int64
#  11  total_conference_wins    99 non-null     int64
#  12  total_conference_losses  99 non-null     int64
#  13  total_conference_ties    99 non-null     int64
#  14  total_home_games         99 non-null     int64
#  15  total_home_wins          99 non-null     int64
#  16  total__home_losses       99 non-null     int64
#  17  total__home_ties         99 non-null     int64
#  18  total_away_games         99 non-null     int64
#  19  total_away_wins          99 non-null     int64
#  20  total_away_losses        99 non-null     int64
#  21  total_away_ties          99 non-null     int64
# dtypes: float64(1), int64(18), object(3)
# memory usage: 17.1+ KB

# %%
df['division'].replace('', 'Not Applicable', inplace=True)

# %%
df
# Out:
#     year  team_id            team        conference        division  \
# 0   1918      127  Michigan State  FBS Independents  Not Applicable
# 1   1925      127  Michigan State  FBS Independents  Not Applicable
# 2   1926      127  Michigan State  FBS Independents  Not Applicable
# 3   1927      127  Michigan State  FBS Independents  Not Applicable
# 4   1928      127  Michigan State  FBS Independents  Not Applicable
# ..   ...      ...             ...               ...             ...
# 94  2019      127  Michigan State           Big Ten            East
# 95  2020      127  Michigan State           Big Ten            East
# 96  2021      127  Michigan State           Big Ten            East
# 97  2022      127  Michigan State           Big Ten            East
# 98  2023      127  Michigan State           Big Ten            East
#
#     expected_wins  total_games  total_wins  total_losses  total_ties  ...  \
# 0             0.0            7           4             3           0  ...
# 1             0.0            8           3             5           0  ...
# 2             0.0            8           3             5           0  ...
# 3             0.0            9           4             5           0  ...
# 4             0.0            8           3             5           0  ...
# ..            ...          ...         ...           ...         ...  ...
# 94            8.3           13           7             6           0  ...
# 95            2.6            7           2             5           0  ...
# 96            9.2           13          11             2           0  ...
# 97            3.9           12           5             7           0  ...
# 98            3.2            8           2             6           0  ...
#
#     total_conference_losses  total_conference_ties  total_home_games  \
# 0                         0                      0                 5
# 1                         2                      0                 5
# 2                         2                      0                 4
# 3                         1                      0                 5
# 4                         2                      0                 5
# ..                      ...                    ...               ...
# 94                        5                      0                 7
# 95                        5                      0                 4
# 96                        2                      0                 6
# 97                        6                      0                 7
# 98                        5                      0                 5
#
#     total_home_wins  total__home_losses  total__home_ties  total_away_games  \
# 0                 4                   1                 0                 2
# 1                 3                   2                 0                 3
# 2                 3                   1                 0                 4
# 3                 4                   1                 0                 4
# 4                 3                   2                 0                 3
# ..              ...                 ...               ...               ...
# 94                4                   3                 0                 5
# 95                1                   3                 0                 3
# 96                6                   0                 0                 6
# 97                4                   3                 0                 5
# 98                2                   3                 0                 3
#
#     total_away_wins  total_away_losses  total_away_ties
# 0                 0                  2                0
# 1                 0                  3                0
# 2                 0                  4                0
# 3                 0                  4                0
# 4                 0                  3                0
# ..              ...                ...              ...
# 94                2                  3                0
# 95                1                  2                0
# 96                4                  2                0
# 97                1                  4                0
# 98                0                  3                0
#
# [99 rows x 22 columns]
