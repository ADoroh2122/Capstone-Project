# %%
import requests
import pandas as pd
import streamlit as st
import cfbd
import sqlalchemy.dialects

# %%
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = 'XscFL3JKpF/UVy2fexpow+vZ/o6rlKfxtnQdN70yVY89w1aTyXYDO+o641kfK8zy'
configuration.api_key_prefix['Authorization'] = 'Bearer'

api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))


fav_team = input('What is your favorite team: ')
records = api_instance.get_team_records(team = f'{fav_team}')

# %%
df = pd.DataFrame.from_records([g.to_dict() for g in records])
df
# Out:
#     year  team_id            team        conference division  expected_wins  \
# 0   1918      127  Michigan State  FBS Independents                     0.0
# 1   1925      127  Michigan State  FBS Independents                     0.0
# 2   1926      127  Michigan State  FBS Independents                     0.0
# 3   1927      127  Michigan State  FBS Independents                     0.0
# 4   1928      127  Michigan State  FBS Independents                     0.0
# ..   ...      ...             ...               ...      ...            ...
# 94  2019      127  Michigan State           Big Ten     East            8.3
# 95  2020      127  Michigan State           Big Ten     East            2.6
# 96  2021      127  Michigan State           Big Ten     East            9.2
# 97  2022      127  Michigan State           Big Ten     East            3.9
# 98  2023      127  Michigan State           Big Ten     East            3.2
#
#                                                 total  \
# 0     {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 1     {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
# 2     {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
# 3     {'games': 9, 'wins': 4, 'losses': 5, 'ties': 0}
# 4     {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
# ..                                                ...
# 94   {'games': 13, 'wins': 7, 'losses': 6, 'ties': 0}
# 95    {'games': 7, 'wins': 2, 'losses': 5, 'ties': 0}
# 96  {'games': 13, 'wins': 11, 'losses': 2, 'ties': 0}
# 97   {'games': 12, 'wins': 5, 'losses': 7, 'ties': 0}
# 98    {'games': 8, 'wins': 2, 'losses': 6, 'ties': 0}
#
#                                    conference_games  \
# 0   {'games': 1, 'wins': 1, 'losses': 0, 'ties': 0}
# 1   {'games': 3, 'wins': 1, 'losses': 2, 'ties': 0}
# 2   {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}
# 3   {'games': 1, 'wins': 0, 'losses': 1, 'ties': 0}
# 4   {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}
# ..                                              ...
# 94  {'games': 9, 'wins': 4, 'losses': 5, 'ties': 0}
# 95  {'games': 7, 'wins': 2, 'losses': 5, 'ties': 0}
# 96  {'games': 9, 'wins': 7, 'losses': 2, 'ties': 0}
# 97  {'games': 9, 'wins': 3, 'losses': 6, 'ties': 0}
# 98  {'games': 5, 'wins': 0, 'losses': 5, 'ties': 0}
#
#                                          home_games  \
# 0   {'games': 5, 'wins': 4, 'losses': 1, 'ties': 0}
# 1   {'games': 5, 'wins': 3, 'losses': 2, 'ties': 0}
# 2   {'games': 4, 'wins': 3, 'losses': 1, 'ties': 0}
# 3   {'games': 5, 'wins': 4, 'losses': 1, 'ties': 0}
# 4   {'games': 5, 'wins': 3, 'losses': 2, 'ties': 0}
# ..                                              ...
# 94  {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 95  {'games': 4, 'wins': 1, 'losses': 3, 'ties': 0}
# 96  {'games': 6, 'wins': 6, 'losses': 0, 'ties': 0}
# 97  {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 98  {'games': 5, 'wins': 2, 'losses': 3, 'ties': 0}
#
#                                          away_games
# 0   {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}
# 1   {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}
# 2   {'games': 4, 'wins': 0, 'losses': 4, 'ties': 0}
# 3   {'games': 4, 'wins': 0, 'losses': 4, 'ties': 0}
# 4   {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}
# ..                                              ...
# 94  {'games': 5, 'wins': 2, 'losses': 3, 'ties': 0}
# 95  {'games': 3, 'wins': 1, 'losses': 2, 'ties': 0}
# 96  {'games': 6, 'wins': 4, 'losses': 2, 'ties': 0}
# 97  {'games': 5, 'wins': 1, 'losses': 4, 'ties': 0}
# 98  {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}
#
# [99 rows x 10 columns]

# %%
data = pd.json_normalize(df['total'])
data
# Out:
#     games  wins  losses  ties
# 0       7     4       3     0
# 1       8     3       5     0
# 2       8     3       5     0
# 3       9     4       5     0
# 4       8     3       5     0
# ..    ...   ...     ...   ...
# 94     13     7       6     0
# 95      7     2       5     0
# 96     13    11       2     0
# 97     12     5       7     0
# 98      8     2       6     0
#
# [99 rows x 4 columns]

# %%
df['total_games'] = data['games']

# %%
df['total_wins'] = data['wins']

# %%
df['total_losses'] = data['losses']

# %%
df['total_ties'] = data['ties']

# %%
data1 = pd.json_normalize(df['conference_games'])

# %%
df['total_conference_games'] = data1['games']

# %%
df['total_conference_wins'] = data1['wins']

# %%
df['total_conference_losses'] = data1['losses']

# %%
df['total_conference_ties'] = data1['ties']

# %%
df.head(2)
# Out:
#    year  team_id            team        conference division  expected_wins  \
# 0  1918      127  Michigan State  FBS Independents                     0.0
# 1  1925      127  Michigan State  FBS Independents                     0.0
#
#                                              total  \
# 0  {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 1  {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
#
#                                   conference_games  \
# 0  {'games': 1, 'wins': 1, 'losses': 0, 'ties': 0}
# 1  {'games': 3, 'wins': 1, 'losses': 2, 'ties': 0}
#
#                                         home_games  \
# 0  {'games': 5, 'wins': 4, 'losses': 1, 'ties': 0}
# 1  {'games': 5, 'wins': 3, 'losses': 2, 'ties': 0}
#
#                                         away_games  total_games  total_wins  \
# 0  {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}            7           4
# 1  {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}            8           3
#
#    total_losses  total_ties  total_conference_games  total_conference_wins  \
# 0             3           0                       1                      1
# 1             5           0                       3                      1
#
#    total_conference_losses  total_conference_ties
# 0                        0                      0
# 1                        2                      0

# %%
data2 = pd.json_normalize(df['home_games'])

# %%
df['total_home_games'] = data2['games']

# %%
df['total_home_wins'] = data2['wins']

# %%
df['total__home_losses'] = data2['losses']

# %%
df['total__home_ties'] = data2['ties']

# %%
df.head(2)
# Out:
#    year  team_id            team        conference division  expected_wins  \
# 0  1918      127  Michigan State  FBS Independents                     0.0
# 1  1925      127  Michigan State  FBS Independents                     0.0
#
#                                              total  \
# 0  {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 1  {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
#
#                                   conference_games  \
# 0  {'games': 1, 'wins': 1, 'losses': 0, 'ties': 0}
# 1  {'games': 3, 'wins': 1, 'losses': 2, 'ties': 0}
#
#                                         home_games  \
# 0  {'games': 5, 'wins': 4, 'losses': 1, 'ties': 0}
# 1  {'games': 5, 'wins': 3, 'losses': 2, 'ties': 0}
#
#                                         away_games  ...  total_losses  \
# 0  {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}  ...             3
# 1  {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}  ...             5
#
#    total_ties  total_conference_games  total_conference_wins  \
# 0           0                       1                      1
# 1           0                       3                      1
#
#    total_conference_losses  total_conference_ties  total_home_games  \
# 0                        0                      0                 5
# 1                        2                      0                 5
#
#    total_home_wins  total__home_losses  total__home_ties
# 0                4                   1                 0
# 1                3                   2                 0
#
# [2 rows x 22 columns]

# %%
data3 = pd.json_normalize(df['away_games'])

# %%
df['total_away_games'] = data3['games']

# %%
df['total_away_wins'] = data3['wins']

# %%
df['total_away_losses'] = data3['losses']

# %%
df['total_away_ties'] = data3['ties']

# %%
df.head(2)
# Out:
#    year  team_id            team        conference division  expected_wins  \
# 0  1918      127  Michigan State  FBS Independents                     0.0
# 1  1925      127  Michigan State  FBS Independents                     0.0
#
#                                              total  \
# 0  {'games': 7, 'wins': 4, 'losses': 3, 'ties': 0}
# 1  {'games': 8, 'wins': 3, 'losses': 5, 'ties': 0}
#
#                                   conference_games  \
# 0  {'games': 1, 'wins': 1, 'losses': 0, 'ties': 0}
# 1  {'games': 3, 'wins': 1, 'losses': 2, 'ties': 0}
#
#                                         home_games  \
# 0  {'games': 5, 'wins': 4, 'losses': 1, 'ties': 0}
# 1  {'games': 5, 'wins': 3, 'losses': 2, 'ties': 0}
#
#                                         away_games  ...  \
# 0  {'games': 2, 'wins': 0, 'losses': 2, 'ties': 0}  ...
# 1  {'games': 3, 'wins': 0, 'losses': 3, 'ties': 0}  ...
#
#    total_conference_losses  total_conference_ties  total_home_games  \
# 0                        0                      0                 5
# 1                        2                      0                 5
#
#    total_home_wins  total__home_losses  total__home_ties  total_away_games  \
# 0                4                   1                 0                 2
# 1                3                   2                 0                 3
#
#    total_away_wins  total_away_losses  total_away_ties
# 0                0                  2                0
# 1                0                  3                0
#
# [2 rows x 26 columns]

# %%
del df['total']

# %%
del df['conference_games']

# %%
del df['home_games']

# %%
del df['away_games']

# %%
df.head(2)
# Out:
#    year  team_id            team        conference division  expected_wins  \
# 0  1918      127  Michigan State  FBS Independents                     0.0
# 1  1925      127  Michigan State  FBS Independents                     0.0
#
#    total_games  total_wins  total_losses  total_ties  ...  \
# 0            7           4             3           0  ...
# 1            8           3             5           0  ...
#
#    total_conference_losses  total_conference_ties  total_home_games  \
# 0                        0                      0                 5
# 1                        2                      0                 5
#
#    total_home_wins  total__home_losses  total__home_ties  total_away_games  \
# 0                4                   1                 0                 2
# 1                3                   2                 0                 3
#
#    total_away_wins  total_away_losses  total_away_ties
# 0                0                  2                0
# 1                0                  3                0
#
# [2 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     99 non-null     int64
#  1   team_id                  99 non-null     int64
#  2   team                     99 non-null     object
#  3   conference               99 non-null     object
#  4   division                 99 non-null     object
#  5   expected_wins            99 non-null     float64
#  6   total_games              99 non-null     int64
#  7   total_wins               99 non-null     int64
#  8   total_losses             99 non-null     int64
#  9   total_ties               99 non-null     int64
#  10  total_conference_games   99 non-null     int64
#  11  total_conference_wins    99 non-null     int64
#  12  total_conference_losses  99 non-null     int64
#  13  total_conference_ties    99 non-null     int64
#  14  total_home_games         99 non-null     int64
#  15  total_home_wins          99 non-null     int64
#  16  total__home_losses       99 non-null     int64
#  17  total__home_ties         99 non-null     int64
#  18  total_away_games         99 non-null     int64
#  19  total_away_wins          99 non-null     int64
#  20  total_away_losses        99 non-null     int64
#  21  total_away_ties          99 non-null     int64
# dtypes: float64(1), int64(18), object(3)
# memory usage: 17.1+ KB

# %%
df['division'].replace('', 'Not Applicable', inplace=True)

# %%
df
# Out:
#     year  team_id            team        conference        division  \
# 0   1918      127  Michigan State  FBS Independents  Not Applicable
# 1   1925      127  Michigan State  FBS Independents  Not Applicable
# 2   1926      127  Michigan State  FBS Independents  Not Applicable
# 3   1927      127  Michigan State  FBS Independents  Not Applicable
# 4   1928      127  Michigan State  FBS Independents  Not Applicable
# ..   ...      ...             ...               ...             ...
# 94  2019      127  Michigan State           Big Ten            East
# 95  2020      127  Michigan State           Big Ten            East
# 96  2021      127  Michigan State           Big Ten            East
# 97  2022      127  Michigan State           Big Ten            East
# 98  2023      127  Michigan State           Big Ten            East
#
#     expected_wins  total_games  total_wins  total_losses  total_ties  ...  \
# 0             0.0            7           4             3           0  ...
# 1             0.0            8           3             5           0  ...
# 2             0.0            8           3             5           0  ...
# 3             0.0            9           4             5           0  ...
# 4             0.0            8           3             5           0  ...
# ..            ...          ...         ...           ...         ...  ...
# 94            8.3           13           7             6           0  ...
# 95            2.6            7           2             5           0  ...
# 96            9.2           13          11             2           0  ...
# 97            3.9           12           5             7           0  ...
# 98            3.2            8           2             6           0  ...
#
#     total_conference_losses  total_conference_ties  total_home_games  \
# 0                         0                      0                 5
# 1                         2                      0                 5
# 2                         2                      0                 4
# 3                         1                      0                 5
# 4                         2                      0                 5
# ..                      ...                    ...               ...
# 94                        5                      0                 7
# 95                        5                      0                 4
# 96                        2                      0                 6
# 97                        6                      0                 7
# 98                        5                      0                 5
#
#     total_home_wins  total__home_losses  total__home_ties  total_away_games  \
# 0                 4                   1                 0                 2
# 1                 3                   2                 0                 3
# 2                 3                   1                 0                 4
# 3                 4                   1                 0                 4
# 4                 3                   2                 0                 3
# ..              ...                 ...               ...               ...
# 94                4                   3                 0                 5
# 95                1                   3                 0                 3
# 96                6                   0                 0                 6
# 97                4                   3                 0                 5
# 98                2                   3                 0                 3
#
#     total_away_wins  total_away_losses  total_away_ties
# 0                 0                  2                0
# 1                 0                  3                0
# 2                 0                  4                0
# 3                 0                  4                0
# 4                 0                  3                0
# ..              ...                ...              ...
# 94                2                  3                0
# 95                1                  2                0
# 96                4                  2                0
# 97                1                  4                0
# 98                0                  3                0
#
# [99 rows x 22 columns]

# %%
# Connecting to Elephant SQL

connection = 'postgresql://lbgowpbc:dNYHpRnfDLZbvt4iBvVhp11ziizGwLlI@castor.db.elephantsql.com/lbgowpbc'

# %%
df.to_sql('team_records', index=False, con = connection, if_exists = 'append')
# Out:
# 99

# %%
df.to_csv('data/new_team_records.csv', index=False)

# %%
df = pd.read_csv('data/new_team_records.csv')
df
# Out:
#     year  team_id            team        conference        division  \
# 0   1918      127  Michigan State  FBS Independents  Not Applicable
# 1   1925      127  Michigan State  FBS Independents  Not Applicable
# 2   1926      127  Michigan State  FBS Independents  Not Applicable
# 3   1927      127  Michigan State  FBS Independents  Not Applicable
# 4   1928      127  Michigan State  FBS Independents  Not Applicable
# ..   ...      ...             ...               ...             ...
# 94  2019      127  Michigan State           Big Ten            East
# 95  2020      127  Michigan State           Big Ten            East
# 96  2021      127  Michigan State           Big Ten            East
# 97  2022      127  Michigan State           Big Ten            East
# 98  2023      127  Michigan State           Big Ten            East
#
#     expected_wins  total_games  total_wins  total_losses  total_ties  ...  \
# 0             0.0            7           4             3           0  ...
# 1             0.0            8           3             5           0  ...
# 2             0.0            8           3             5           0  ...
# 3             0.0            9           4             5           0  ...
# 4             0.0            8           3             5           0  ...
# ..            ...          ...         ...           ...         ...  ...
# 94            8.3           13           7             6           0  ...
# 95            2.6            7           2             5           0  ...
# 96            9.2           13          11             2           0  ...
# 97            3.9           12           5             7           0  ...
# 98            3.2            8           2             6           0  ...
#
#     total_conference_losses  total_conference_ties  total_home_games  \
# 0                         0                      0                 5
# 1                         2                      0                 5
# 2                         2                      0                 4
# 3                         1                      0                 5
# 4                         2                      0                 5
# ..                      ...                    ...               ...
# 94                        5                      0                 7
# 95                        5                      0                 4
# 96                        2                      0                 6
# 97                        6                      0                 7
# 98                        5                      0                 5
#
#     total_home_wins  total__home_losses  total__home_ties  total_away_games  \
# 0                 4                   1                 0                 2
# 1                 3                   2                 0                 3
# 2                 3                   1                 0                 4
# 3                 4                   1                 0                 4
# 4                 3                   2                 0                 3
# ..              ...                 ...               ...               ...
# 94                4                   3                 0                 5
# 95                1                   3                 0                 3
# 96                6                   0                 0                 6
# 97                4                   3                 0                 5
# 98                2                   3                 0                 3
#
#     total_away_wins  total_away_losses  total_away_ties
# 0                 0                  2                0
# 1                 0                  3                0
# 2                 0                  4                0
# 3                 0                  4                0
# 4                 0                  3                0
# ..              ...                ...              ...
# 94                2                  3                0
# 95                1                  2                0
# 96                4                  2                0
# 97                1                  4                0
# 98                0                  3                0
#
# [99 rows x 22 columns]

# %%
df['year'] = df['year'].replace(',', '', regex=True)

# %%
df
# Out:
#     year  team_id            team        conference        division  \
# 0   1918      127  Michigan State  FBS Independents  Not Applicable
# 1   1925      127  Michigan State  FBS Independents  Not Applicable
# 2   1926      127  Michigan State  FBS Independents  Not Applicable
# 3   1927      127  Michigan State  FBS Independents  Not Applicable
# 4   1928      127  Michigan State  FBS Independents  Not Applicable
# ..   ...      ...             ...               ...             ...
# 94  2019      127  Michigan State           Big Ten            East
# 95  2020      127  Michigan State           Big Ten            East
# 96  2021      127  Michigan State           Big Ten            East
# 97  2022      127  Michigan State           Big Ten            East
# 98  2023      127  Michigan State           Big Ten            East
#
#     expected_wins  total_games  total_wins  total_losses  total_ties  ...  \
# 0             0.0            7           4             3           0  ...
# 1             0.0            8           3             5           0  ...
# 2             0.0            8           3             5           0  ...
# 3             0.0            9           4             5           0  ...
# 4             0.0            8           3             5           0  ...
# ..            ...          ...         ...           ...         ...  ...
# 94            8.3           13           7             6           0  ...
# 95            2.6            7           2             5           0  ...
# 96            9.2           13          11             2           0  ...
# 97            3.9           12           5             7           0  ...
# 98            3.2            8           2             6           0  ...
#
#     total_conference_losses  total_conference_ties  total_home_games  \
# 0                         0                      0                 5
# 1                         2                      0                 5
# 2                         2                      0                 4
# 3                         1                      0                 5
# 4                         2                      0                 5
# ..                      ...                    ...               ...
# 94                        5                      0                 7
# 95                        5                      0                 4
# 96                        2                      0                 6
# 97                        6                      0                 7
# 98                        5                      0                 5
#
#     total_home_wins  total__home_losses  total__home_ties  total_away_games  \
# 0                 4                   1                 0                 2
# 1                 3                   2                 0                 3
# 2                 3                   1                 0                 4
# 3                 4                   1                 0                 4
# 4                 3                   2                 0                 3
# ..              ...                 ...               ...               ...
# 94                4                   3                 0                 5
# 95                1                   3                 0                 3
# 96                6                   0                 0                 6
# 97                4                   3                 0                 5
# 98                2                   3                 0                 3
#
#     total_away_wins  total_away_losses  total_away_ties
# 0                 0                  2                0
# 1                 0                  3                0
# 2                 0                  4                0
# 3                 0                  4                0
# 4                 0                  3                0
# ..              ...                ...              ...
# 94                2                  3                0
# 95                1                  2                0
# 96                4                  2                0
# 97                1                  4                0
# 98                0                  3                0
#
# [99 rows x 22 columns]

# %%
from __future__ import print_function
import time
import cfbd
from cfbd.rest import ApiException
from pprint import pprint

# Configure API key authorization: ApiKeyAuth
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = 'XscFL3JKpF/UVy2fexpow+vZ/o6rlKfxtnQdN70yVY89w1aTyXYDO+o641kfK8zy'
# Uncomment below to setup prefix (e.g. Bearer) for API key, if needed
configuration.api_key_prefix['Authorization'] = 'Bearer'

# create an instance of the API class
api_instance = cfbd.TeamsApi(cfbd.ApiClient(configuration))
team1 = 'Michigan State' # str | First team
team2 = 'Michigan' # str | Second team

try:
    # Team matchup history
    api_response = api_instance.get_team_matchup(team1, team2)
    pprint(api_response)
except ApiException as e:
    print("Exception when calling TeamsApi->get_team_matchup: %s\n" % e)
# Out:
# {'end_year': None,
#  'games': [{'_date': '1898-10-12T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 39,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1898,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1902-10-08T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 119,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1902,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan'},
#            {'_date': '1907-10-12T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 46,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1907,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1908-10-10T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 0,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1908,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': None},
#            {'_date': '1910-10-15T00:00:00.000Z',
#             'away_score': 3,
#             'away_team': 'Michigan State',
#             'home_score': 6,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1910,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan'},
#            {'_date': '1911-10-14T00:00:00.000Z',
#             'away_score': 15,
#             'away_team': 'Michigan',
#             'home_score': 3,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1911,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1912-10-12T00:00:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan State',
#             'home_score': 55,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1912,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1913-10-18T00:00:00.000Z',
#             'away_score': 12,
#             'away_team': 'Michigan State',
#             'home_score': 7,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1913,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan State'},
#            {'_date': '1914-10-17T00:00:00.000Z',
#             'away_score': 3,
#             'away_team': 'Michigan',
#             'home_score': 0,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1914,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan'},
#            {'_date': '1915-10-23T00:00:00.000Z',
#             'away_score': 24,
#             'away_team': 'Michigan State',
#             'home_score': 0,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1915,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan State'},
#            {'_date': '1916-10-21T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 9,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1916,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1917-10-20T00:00:00.000Z',
#             'away_score': 27,
#             'away_team': 'Michigan',
#             'home_score': 0,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1917,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1918-11-23T00:00:00.000Z',
#             'away_score': 6,
#             'away_team': 'Michigan State',
#             'home_score': 21,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1918,
#             'season_type': None,
#             'venue': None,
#             'week': 9,
#             'winner': 'Michigan'},
#            {'_date': '1919-10-18T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 26,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1919,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan'},
#            {'_date': '1920-10-16T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 35,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1920,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1921-10-15T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 30,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1921,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan'},
#            {'_date': '1922-11-04T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 63,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1922,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1923-10-27T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 37,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1923,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1924-10-11T00:00:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan',
#             'home_score': 0,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1924,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1925-10-03T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 39,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1925,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan'},
#            {'_date': '1926-10-09T00:00:00.000Z',
#             'away_score': 3,
#             'away_team': 'Michigan State',
#             'home_score': 55,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1926,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1927-10-08T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 21,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1927,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1928-11-17T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 3,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1928,
#             'season_type': None,
#             'venue': None,
#             'week': 11,
#             'winner': 'Michigan'},
#            {'_date': '1929-10-05T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 17,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1929,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan'},
#            {'_date': '1930-10-04T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan',
#             'home_score': 0,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1930,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': None},
#            {'_date': '1931-11-14T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan',
#             'home_score': 0,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1931,
#             'season_type': None,
#             'venue': None,
#             'week': 10,
#             'winner': None},
#            {'_date': '1932-10-01T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 26,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1932,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan'},
#            {'_date': '1933-10-07T00:00:00.000Z',
#             'away_score': 6,
#             'away_team': 'Michigan State',
#             'home_score': 20,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1933,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1934-10-06T00:00:00.000Z',
#             'away_score': 16,
#             'away_team': 'Michigan State',
#             'home_score': 0,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1934,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan State'},
#            {'_date': '1935-10-05T00:00:00.000Z',
#             'away_score': 25,
#             'away_team': 'Michigan State',
#             'home_score': 6,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1935,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan State'},
#            {'_date': '1936-10-03T00:00:00.000Z',
#             'away_score': 21,
#             'away_team': 'Michigan State',
#             'home_score': 7,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1936,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan State'},
#            {'_date': '1937-10-02T00:00:00.000Z',
#             'away_score': 19,
#             'away_team': 'Michigan State',
#             'home_score': 14,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1937,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan State'},
#            {'_date': '1938-10-01T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 14,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1938,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan'},
#            {'_date': '1939-10-07T00:00:00.000Z',
#             'away_score': 13,
#             'away_team': 'Michigan State',
#             'home_score': 26,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1939,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1940-10-05T00:00:00.000Z',
#             'away_score': 14,
#             'away_team': 'Michigan State',
#             'home_score': 21,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1940,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1941-09-27T00:00:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan State',
#             'home_score': 19,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1941,
#             'season_type': None,
#             'venue': None,
#             'week': 2,
#             'winner': 'Michigan'},
#            {'_date': '1942-10-03T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 20,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1942,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1945-09-29T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 40,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1945,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan'},
#            {'_date': '1946-11-09T00:00:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan State',
#             'home_score': 55,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1946,
#             'season_type': None,
#             'venue': None,
#             'week': 9,
#             'winner': 'Michigan'},
#            {'_date': '1947-09-27T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 55,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1947,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan'},
#            {'_date': '1948-09-25T00:00:00.000Z',
#             'away_score': 13,
#             'away_team': 'Michigan',
#             'home_score': 7,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1948,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan'},
#            {'_date': '1949-09-24T00:00:00.000Z',
#             'away_score': 3,
#             'away_team': 'Michigan State',
#             'home_score': 7,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1949,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan'},
#            {'_date': '1950-09-30T00:00:00.000Z',
#             'away_score': 14,
#             'away_team': 'Michigan State',
#             'home_score': 7,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1950,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan State'},
#            {'_date': '1951-09-29T00:00:00.000Z',
#             'away_score': 25,
#             'away_team': 'Michigan State',
#             'home_score': 0,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1951,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan State'},
#            {'_date': '1952-09-27T00:00:00.000Z',
#             'away_score': 27,
#             'away_team': 'Michigan State',
#             'home_score': 13,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1952,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan State'},
#            {'_date': '1953-11-14T00:00:00.000Z',
#             'away_score': 6,
#             'away_team': 'Michigan',
#             'home_score': 14,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1953,
#             'season_type': None,
#             'venue': None,
#             'week': 9,
#             'winner': 'Michigan State'},
#            {'_date': '1954-11-13T00:00:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan State',
#             'home_score': 33,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1954,
#             'season_type': None,
#             'venue': None,
#             'week': 9,
#             'winner': 'Michigan'},
#            {'_date': '1955-10-01T00:00:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan State',
#             'home_score': 14,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1955,
#             'season_type': None,
#             'venue': None,
#             'week': 3,
#             'winner': 'Michigan'},
#            {'_date': '1956-10-06T00:00:00.000Z',
#             'away_score': 9,
#             'away_team': 'Michigan State',
#             'home_score': 0,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1956,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan State'},
#            {'_date': '1957-10-12T00:00:00.000Z',
#             'away_score': 35,
#             'away_team': 'Michigan State',
#             'home_score': 6,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1957,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan State'},
#            {'_date': '1958-10-04T00:00:00.000Z',
#             'away_score': 12,
#             'away_team': 'Michigan State',
#             'home_score': 12,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1958,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': None},
#            {'_date': '1959-10-03T00:00:00.000Z',
#             'away_score': 34,
#             'away_team': 'Michigan State',
#             'home_score': 8,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1959,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan State'},
#            {'_date': '1960-10-01T00:00:00.000Z',
#             'away_score': 17,
#             'away_team': 'Michigan',
#             'home_score': 24,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1960,
#             'season_type': None,
#             'venue': None,
#             'week': 4,
#             'winner': 'Michigan State'},
#            {'_date': '1961-10-14T00:00:00.000Z',
#             'away_score': 28,
#             'away_team': 'Michigan State',
#             'home_score': 0,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1961,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan State'},
#            {'_date': '1962-10-13T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan',
#             'home_score': 28,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1962,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan State'},
#            {'_date': '1963-10-12T00:00:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan',
#             'home_score': 7,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1963,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': None},
#            {'_date': '1964-10-10T00:00:00.000Z',
#             'away_score': 17,
#             'away_team': 'Michigan',
#             'home_score': 10,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1964,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan'},
#            {'_date': '1965-10-09T00:00:00.000Z',
#             'away_score': 24,
#             'away_team': 'Michigan State',
#             'home_score': 7,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1965,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan State'},
#            {'_date': '1966-10-08T00:00:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan',
#             'home_score': 20,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1966,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan State'},
#            {'_date': '1967-10-14T00:00:00.000Z',
#             'away_score': 34,
#             'away_team': 'Michigan State',
#             'home_score': 0,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1967,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan State'},
#            {'_date': '1968-10-12T00:00:00.000Z',
#             'away_score': 14,
#             'away_team': 'Michigan State',
#             'home_score': 28,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1968,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan'},
#            {'_date': '1969-10-18T00:00:00.000Z',
#             'away_score': 12,
#             'away_team': 'Michigan',
#             'home_score': 23,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1969,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan State'},
#            {'_date': '1970-10-17T00:00:00.000Z',
#             'away_score': 20,
#             'away_team': 'Michigan State',
#             'home_score': 34,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1970,
#             'season_type': None,
#             'venue': None,
#             'week': 8,
#             'winner': 'Michigan'},
#            {'_date': '1971-10-09T00:00:00.000Z',
#             'away_score': 24,
#             'away_team': 'Michigan',
#             'home_score': 13,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1971,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan'},
#            {'_date': '1972-10-14T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 10,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1972,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1973-10-13T00:00:00.000Z',
#             'away_score': 31,
#             'away_team': 'Michigan',
#             'home_score': 0,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1973,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1974-10-12T00:00:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan State',
#             'home_score': 21,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1974,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1975-10-11T00:00:00.000Z',
#             'away_score': 16,
#             'away_team': 'Michigan',
#             'home_score': 6,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1975,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1976-10-09T00:00:00.000Z',
#             'away_score': 10,
#             'away_team': 'Michigan State',
#             'home_score': 42,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1976,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1977-10-08T00:00:00.000Z',
#             'away_score': 24,
#             'away_team': 'Michigan',
#             'home_score': 14,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1977,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1978-10-14T00:00:00.000Z',
#             'away_score': 24,
#             'away_team': 'Michigan State',
#             'home_score': 15,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1978,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan State'},
#            {'_date': '1979-10-06T00:00:00.000Z',
#             'away_score': 21,
#             'away_team': 'Michigan',
#             'home_score': 7,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1979,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1980-10-11T00:00:00.000Z',
#             'away_score': 23,
#             'away_team': 'Michigan State',
#             'home_score': 27,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1980,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1981-10-10T00:00:00.000Z',
#             'away_score': 38,
#             'away_team': 'Michigan',
#             'home_score': 20,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1981,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1982-10-09T00:00:00.000Z',
#             'away_score': 17,
#             'away_team': 'Michigan State',
#             'home_score': 31,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1982,
#             'season_type': None,
#             'venue': None,
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '1983-10-08T00:00:00.000Z',
#             'away_score': 42,
#             'away_team': 'Michigan',
#             'home_score': 0,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1983,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1984-10-06T00:00:00.000Z',
#             'away_score': 19,
#             'away_team': 'Michigan State',
#             'home_score': 7,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1984,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan State'},
#            {'_date': '1985-10-12T00:00:00.000Z',
#             'away_score': 31,
#             'away_team': 'Michigan',
#             'home_score': 0,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1985,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1986-10-11T00:00:00.000Z',
#             'away_score': 6,
#             'away_team': 'Michigan State',
#             'home_score': 27,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1986,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1987-10-10T00:00:00.000Z',
#             'away_score': 11,
#             'away_team': 'Michigan',
#             'home_score': 17,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1987,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan State'},
#            {'_date': '1988-10-08T00:00:00.000Z',
#             'away_score': 3,
#             'away_team': 'Michigan State',
#             'home_score': 17,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1988,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1989-10-14T00:00:00.000Z',
#             'away_score': 10,
#             'away_team': 'Michigan',
#             'home_score': 7,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1989,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1990-10-13T00:00:00.000Z',
#             'away_score': 28,
#             'away_team': 'Michigan State',
#             'home_score': 27,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1990,
#             'season_type': None,
#             'venue': None,
#             'week': 8,
#             'winner': 'Michigan State'},
#            {'_date': '1991-10-12T00:00:00.000Z',
#             'away_score': 45,
#             'away_team': 'Michigan',
#             'home_score': 28,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1991,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1992-10-10T00:00:00.000Z',
#             'away_score': 10,
#             'away_team': 'Michigan State',
#             'home_score': 35,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1992,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1993-10-09T00:00:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan',
#             'home_score': 17,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1993,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan State'},
#            {'_date': '1994-10-08T00:00:00.000Z',
#             'away_score': 20,
#             'away_team': 'Michigan State',
#             'home_score': 40,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1994,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan'},
#            {'_date': '1995-11-04T00:00:00.000Z',
#             'away_score': 25,
#             'away_team': 'Michigan',
#             'home_score': 28,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1995,
#             'season_type': None,
#             'venue': None,
#             'week': 11,
#             'winner': 'Michigan State'},
#            {'_date': '1996-11-02T00:00:00.000Z',
#             'away_score': 29,
#             'away_team': 'Michigan State',
#             'home_score': 45,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1996,
#             'season_type': None,
#             'venue': None,
#             'week': 11,
#             'winner': 'Michigan'},
#            {'_date': '1997-10-25T00:00:00.000Z',
#             'away_score': 23,
#             'away_team': 'Michigan',
#             'home_score': 7,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1997,
#             'season_type': None,
#             'venue': None,
#             'week': 10,
#             'winner': 'Michigan'},
#            {'_date': '1998-09-26T00:00:00.000Z',
#             'away_score': 17,
#             'away_team': 'Michigan State',
#             'home_score': 29,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 1998,
#             'season_type': None,
#             'venue': None,
#             'week': 5,
#             'winner': 'Michigan'},
#            {'_date': '1999-10-09T00:00:00.000Z',
#             'away_score': 31,
#             'away_team': 'Michigan',
#             'home_score': 34,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 1999,
#             'season_type': None,
#             'venue': None,
#             'week': 7,
#             'winner': 'Michigan State'},
#            {'_date': '2000-10-21T00:00:00.000Z',
#             'away_score': 0,
#             'away_team': 'Michigan State',
#             'home_score': 14,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2000,
#             'season_type': None,
#             'venue': None,
#             'week': 9,
#             'winner': 'Michigan'},
#            {'_date': '2001-11-03T21:30:00.000Z',
#             'away_score': 24,
#             'away_team': 'Michigan',
#             'home_score': 26,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2001,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 11,
#             'winner': 'Michigan State'},
#            {'_date': '2002-11-02T18:05:00.000Z',
#             'away_score': 3,
#             'away_team': 'Michigan State',
#             'home_score': 49,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2002,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 11,
#             'winner': 'Michigan'},
#            {'_date': '2003-11-01T18:00:00.000Z',
#             'away_score': 27,
#             'away_team': 'Michigan',
#             'home_score': 20,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2003,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 11,
#             'winner': 'Michigan'},
#            {'_date': '2004-10-30T19:30:00.000Z',
#             'away_score': 37,
#             'away_team': 'Michigan State',
#             'home_score': 45,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2004,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 10,
#             'winner': 'Michigan'},
#            {'_date': '2005-10-01T16:00:00.000Z',
#             'away_score': 34,
#             'away_team': 'Michigan',
#             'home_score': 31,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2005,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 5,
#             'winner': 'Michigan'},
#            {'_date': '2006-10-07T20:30:00.000Z',
#             'away_score': 13,
#             'away_team': 'Michigan State',
#             'home_score': 31,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2006,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 6,
#             'winner': 'Michigan'},
#            {'_date': '2007-11-03T19:30:00.000Z',
#             'away_score': 28,
#             'away_team': 'Michigan',
#             'home_score': 24,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2007,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 10,
#             'winner': 'Michigan'},
#            {'_date': '2008-10-25T19:30:00.000Z',
#             'away_score': 35,
#             'away_team': 'Michigan State',
#             'home_score': 21,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2008,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 9,
#             'winner': 'Michigan State'},
#            {'_date': '2009-10-03T16:00:00.000Z',
#             'away_score': 20,
#             'away_team': 'Michigan',
#             'home_score': 26,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2009,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 5,
#             'winner': 'Michigan State'},
#            {'_date': '2010-10-09T19:30:00.000Z',
#             'away_score': 34,
#             'away_team': 'Michigan State',
#             'home_score': 17,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2010,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 6,
#             'winner': 'Michigan State'},
#            {'_date': '2011-10-15T16:00:00.000Z',
#             'away_score': 14,
#             'away_team': 'Michigan',
#             'home_score': 28,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2011,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 7,
#             'winner': 'Michigan State'},
#            {'_date': '2012-10-20T19:30:00.000Z',
#             'away_score': 10,
#             'away_team': 'Michigan State',
#             'home_score': 12,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2012,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 8,
#             'winner': 'Michigan'},
#            {'_date': '2013-11-02T19:30:00.000Z',
#             'away_score': 6,
#             'away_team': 'Michigan',
#             'home_score': 29,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2013,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 10,
#             'winner': 'Michigan State'},
#            {'_date': '2014-10-25T19:30:00.000Z',
#             'away_score': 11,
#             'away_team': 'Michigan',
#             'home_score': 35,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2014,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 9,
#             'winner': 'Michigan State'},
#            {'_date': '2015-10-17T19:30:00.000Z',
#             'away_score': 27,
#             'away_team': 'Michigan State',
#             'home_score': 23,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2015,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 7,
#             'winner': 'Michigan State'},
#            {'_date': '2016-10-29T16:00:00.000Z',
#             'away_score': 32,
#             'away_team': 'Michigan',
#             'home_score': 23,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2016,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 9,
#             'winner': 'Michigan'},
#            {'_date': '2017-10-07T23:30:00.000Z',
#             'away_score': 14,
#             'away_team': 'Michigan State',
#             'home_score': 10,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2017,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 6,
#             'winner': 'Michigan State'},
#            {'_date': '2018-10-20T16:00:00.000Z',
#             'away_score': 21,
#             'away_team': 'Michigan',
#             'home_score': 7,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2018,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 8,
#             'winner': 'Michigan'},
#            {'_date': '2019-11-16T17:00:00.000Z',
#             'away_score': 10,
#             'away_team': 'Michigan State',
#             'home_score': 44,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2019,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 12,
#             'winner': 'Michigan'},
#            {'_date': '2020-10-31T16:00:00.000Z',
#             'away_score': 27,
#             'away_team': 'Michigan State',
#             'home_score': 24,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2020,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 9,
#             'winner': 'Michigan State'},
#            {'_date': '2021-10-30T16:00:00.000Z',
#             'away_score': 33,
#             'away_team': 'Michigan',
#             'home_score': 37,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2021,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 9,
#             'winner': 'Michigan State'},
#            {'_date': '2022-10-29T23:30:00.000Z',
#             'away_score': 7,
#             'away_team': 'Michigan State',
#             'home_score': 29,
#             'home_team': 'Michigan',
#             'neutral_site': False,
#             'season': 2022,
#             'season_type': None,
#             'venue': 'Michigan Stadium',
#             'week': 9,
#             'winner': 'Michigan'},
#            {'_date': '2023-10-21T23:30:00.000Z',
#             'away_score': 49,
#             'away_team': 'Michigan',
#             'home_score': 0,
#             'home_team': 'Michigan State',
#             'neutral_site': False,
#             'season': 2023,
#             'season_type': None,
#             'venue': 'Spartan Stadium',
#             'week': 8,
#             'winner': 'Michigan'}],
#  'start_year': None,
#  'team1': 'Michigan State',
#  'team1_wins': 38,
#  'team2': 'Michigan',
#  'team2_wins': 73,
#  'ties': 5}

# %%
api_response_data = api_response

matchup = pd.DataFrame(api_response_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15856\3886545955.py in ?()
#       1 api_response_data = api_response
#       2
# ----> 3 matchup = pd.DataFrame(api_response_data)
#
# c:\Users\adoro\OneDrive\Documents\GitHub\Capstone-Project\venv\Lib\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     837                 )
#     838         # For data is scalar
#     839         else:
#     840             if index is None or columns is None:
# --> 841                 raise ValueError("DataFrame constructor not properly called!")
#     842
#     843             index = ensure_index(index)
#     844             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
